# %% [markdown]
# # User Input Research
# In the evaluation of our report, we discussed the differences between the final performance of both models. However, during our investigation, we suspected that we unintentionally formulated the user inputs to facilitate their use in a TF-IDF model.
#
# Therefore, we will compare the models again, but this time with modified and new user inputs.

# %% [markdown]
# ## 1. Previously Used Student Profiles Adjusted
# Here we will adjust the 3 already known user profile to contain more natural data. The data that they contained earlier cannot be expected from a real user, they don't write in such concise manner. Especially when writing about their personal interests.

# %%
from helpers.notebook_pipelines.not_tuned_se_model import run_evaluation_multi as run_evaluation_multi_se
from helpers.notebook_pipelines.not_tuned_bow_model import run_evaluation_multi as run_evaluation_multi_bow
from helpers.functs.StudentProfile import StudentProfile
from IPython.display import display
import pandas as pd


# Our mocked student profiles
student1 = StudentProfile(
    current_study= "Kunst & Onderzoek",
    interests=[
        "Tekenen",
        "Animatie",
        "Kunst",
        "Drama",
        "Ik hou ervan om mensen te vermaken. Dit doe ik het liefst door bijvoorbeeld te dansen, te zingen of toneelspelen. In het algemeen vind ik het fijn om creatief bezig te zijn. Ik ben graag onder de mensen."
    ],
    wanted_study_credit_range=(15, 30),
    location_preference=["Den Bosch", "Breda", "Tilburg"],
    learning_goals=["Kritisch denken", "Sociale vaardigheden", "Zelfverzekerdheid", "Ik wil o.a. leren hoe ik betere illustraties kan maken zowel analoog als digitaal."],
    level_preference=["NLQF5", "NLQF6"],
    preferred_language="NL",
    preferred_start_range="any"
)

student2 = StudentProfile(
    current_study= "Informatica",
    interests=[
        "Programmeren",
        "AI",
        "Coderen",
        "Techniek",
        "Software",
        "Ik heb werken met computers en techniek van jongs af aan al interessant gevonden. Kunstmatige intelligentie is nu ook zeker iets dat me interesseert, zeker met de sterke opkomst hiervan. Zo kun je denken aan machine learning, deep learning, etc. Ik wil me vooral bezighouden met software."
    ],
    wanted_study_credit_range=(15, 30),
    location_preference=["Den Bosch", "Breda", "Tilburg"],
    learning_goals=["Kritisch denken", "Technische Vaardigheden", "Eén van de dingen die ik wil leren is het toepassen van mijn kennis in de praktijk"],
    level_preference=["NLQF5", "NLQF6"],
    preferred_language="NL",
    preferred_start_range="any"
)

student3 = StudentProfile(
    current_study= "Psychologie",
    interests=[
        "Mensen",
        "Emoties",
        "Gedrag",
        "Psychologie",
        "Ik wil graag weten waarom mensen bepaalde dingen doen; ik wil mensen hun gedrag kunnen begrijpen. Naast hun gedrag wil ik ook leren over, persoonlijkheden en emoties. Graag wil ik mensen hun welzijn kunnen bevorderen met het gebruik van psychologische kennis."
    ],
    wanted_study_credit_range=(15, 30),
    location_preference=["Den Bosch", "Breda", "Tilburg"],
    learning_goals=["Kritisch denken", "Sociale Vaardigheden", "Ik wil leren hoe ik mensen en hun gedrag beter kan analyseren"],
    level_preference=["NLQF5", "NLQF6"],
    preferred_language="NL",
    preferred_start_range="any"
)

# Ground-truth relevant modules per student
matching_models_list = [
    [388, 392, 191, 385, 386, 379, 389, 377, 391, 233],          # student1
    [304, 305, 312, 317, 318, 322, 321, 334, 336, 340, 333],     # student2
    [159, 290, 397, 180, 177, 208, 173, 193, 357]                # student3
]

students = [student1, student2, student3]

# %% [markdown]
# ## Running through SBERT model

# %%
all_results, avg_p_at_k = run_evaluation_multi_se(students, matching_models_list, top_n=5, k=5)

print("Average precision@5 over all students:", avg_p_at_k)

for idx, (student, result) in enumerate(zip(students, all_results), start=1):
    name = getattr(student, "name", f"Student {idx}")
    print("=" * 60)
    print(f"Results for {name} (index {idx}):")
    print(f"precision@5: {result['precision_at_k']:.3f}")

    old_width = pd.get_option("display.max_colwidth")
    pd.set_option("display.max_colwidth", None)
    display(result["recs"])
    pd.set_option("display.max_colwidth", old_width)
# Out:
# Relevant module IDs (ground truth): [191, 233, 377, 379, 385, 386, 388, 389, 391, 392]
# Top-5 recommended IDs: [191, 391, 233, 386, 384]
# Hits in top-5: 4
# precision@5: 0.800
# --------------------------------------------------
# Relevant module IDs (ground truth): [304, 305, 312, 317, 318, 321, 322, 333, 334, 336, 340]
# Top-5 recommended IDs: [333, 366, 171, 340, 226]
# Hits in top-5: 2
# precision@5: 0.400
# --------------------------------------------------
# Relevant module IDs (ground truth): [159, 173, 177, 180, 193, 208, 290, 357, 397]
# Top-5 recommended IDs: [159, 173, 197, 391, 177]
# Hits in top-5: 3
# precision@5: 0.600
# --------------------------------------------------
# Average precision@5 over all students: 0.6000000000000001
# ============================================================
# Results for Student 1 (index 1):
# precision@5: 0.800
#    rank  module_id  \
# 0     1        191
# 1     2        391
# 2     3        233
# 3     4        386
# 4     5        384
#
#                                                    module_name     score  \
# 0                                    De Kracht van de kunsten   0.687917
# 1                     Art & Humanity (nieuwe naam formuleren)   0.667841
# 2  Artistiek ondernemerschap voor kunst, design en performance  0.600675
# 3                                               Graphic Novel   0.599407
# 4                                Development for Storytelling   0.594137
#
#                                                                                                                                                                                    motivation_full
# 0  De Kracht van de kunsten  past heel sterk bij wat jij leuk vindt. Met name jouw beschrijving "Tekenen Animatie Kunst Drama Ik hou ervan om mensen te vermaken" komt sterk terug in deze module.
# 1           Art & Humanity (nieuwe naam formuleren)  sluit extreem goed aan bij jouw profiel. Dit sluit aan bij wat je vertelt: "Tekenen Animatie Kunst Drama Ik hou ervan om mensen te vermaken".
# 2        Deze module is een bijna perfecte match met jouw interesses. Je profiel benadrukt vooral "leren hoe ik betere illustraties kan maken zowel analoog als digitaal", wat hier goed bij past.
# 3          Deze module sluit goed aan bij jouw profiel. Met name jouw beschrijving "Dit doe ik het liefst door bijvoorbeeld te dansen, te zingen of toneelspelen" komt sterk terug in deze module.
# 4                Development for Storytelling  is een sterke match met jouw interesses. Dit sluit aan bij wat je vertelt: "leren hoe ik betere illustraties kan maken zowel analoog als digitaal".
# ============================================================
# Results for Student 2 (index 2):
# precision@5: 0.400
#    rank  module_id                          module_name     score  \
# 0     1        333  Smart Industry & Internet of Things  0.717085
# 1     2        366            Didactiek voor N&G en N&T  0.680460
# 2     3        171       Technologie in zorg en welzijn  0.671237
# 3     4        340                        AI Translator  0.669332
# 4     5        226    Digital Nomads NLQF 6, 30 + 15 EC  0.663012
#
#                                                                                                                                                                                                                                                 motivation_full
# 0            Op basis van jouw antwoorden sluit extreem goed aan bij jouw profiel. Je profiel benadrukt vooral "Kritisch denken Technische Vaardigheden Eén van de dingen die ik wil leren is het toepassen van mijn kennis in de ...", wat hier goed bij past.
# 1                              Op basis van jouw antwoorden is een bijna perfecte match met jouw interesses. Vooral omdat je aangeeft: "Kritisch denken Technische Vaardigheden Eén van de dingen die ik wil leren is het toepassen van mijn kennis in de ...".
# 2  Technologie in zorg en welzijn is een bijna perfecte match met jouw interesses. Je profiel benadrukt vooral "Kritisch denken Technische Vaardigheden Eén van de dingen die ik wil leren is het toepassen van mijn kennis in de ...", wat hier goed bij past.
# 3                        Deze module sluit extreem goed aan bij jouw profiel. Je profiel benadrukt vooral "Programmeren AI Coderen Techniek Software Ik heb werken met computers en techniek van jongs af aan al interessant gevonden", wat hier goed bij past.
# 4   Digital Nomads NLQF 6, 30 + 15 EC past heel sterk bij wat jij leuk vindt. Je profiel benadrukt vooral "Programmeren AI Coderen Techniek Software Ik heb werken met computers en techniek van jongs af aan al interessant gevonden", wat hier goed bij past.
# ============================================================
# Results for Student 3 (index 3):
# precision@5: 0.600
#    rank  module_id                               module_name     score  \
# 0     1        159              Kennismaking met Psychologie  0.641677
# 1     2        173                   Langer thuis in de wijk  0.611109
# 2     3        197                 Werken in gedwongen kader  0.563634
# 3     4        391  Art & Humanity (nieuwe naam formuleren)   0.559185
# 4     5        177                Patronen doorbreken: basis  0.534506
#
#                                                                                                                                                                                                                     motivation_full
# 0  Kennismaking met Psychologie is een bijna perfecte match met jouw interesses. Je profiel benadrukt vooral "Graag wil ik mensen hun welzijn kunnen bevorderen met het gebruik van psychologische kennis", wat hier goed bij past.
# 1                             Op basis van jouw antwoorden past heel sterk bij wat jij leuk vindt. Dit sluit aan bij wat je vertelt: "Graag wil ik mensen hun welzijn kunnen bevorderen met het gebruik van psychologische kennis".
# 2            Werken in gedwongen kader is een sterke match met jouw interesses. Dit sluit aan bij wat je vertelt: "Kritisch denken Sociale Vaardigheden Ik wil leren hoe ik mensen en hun gedrag beter kan analyseren Psychologie".
# 3    Deze module lijkt behoorlijk goed bij jou te passen. We herkennen hierin wat je schreef: "Mensen Emoties Gedrag Psychologie Ik wil graag weten waarom mensen bepaalde dingen doen; ik wil mensen hun gedrag kunnen begrijpen".
# 4                            Patronen doorbreken: basis is een sterke match met jouw interesses. We herkennen hierin wat je schreef: "Graag wil ik mensen hun welzijn kunnen bevorderen met het gebruik van psychologische kennis".

# %% [markdown]
# ## Running through TF-IDF model

# %%
all_results, avg_p_at_k = run_evaluation_multi_bow(students, matching_models_list, top_n=5, k=5)

print("Average precision@5 over all students:", avg_p_at_k)

# Print model output for each student individually
for idx, (student, result) in enumerate(zip(students, all_results), start=1):
    name = getattr(student, "name", f"Student {idx}")
    print("=" * 60)
    print(f"Results for {name} (index {idx}):")
    print(f"precision@5: {result['precision_at_k']:.3f}")

    # Pandas settings for max width columns
    old_width = pd.get_option("display.max_colwidth")
    pd.set_option("display.max_colwidth", None)

    # Show updated recommendations
    display(result["recs"])

    # Restoring original pandas setting
    pd.set_option("display.max_colwidth", old_width)
# Out:
# (211, 12596)
# Relevant module IDs (ground truth): [191, 233, 377, 379, 385, 386, 388, 389, 391, 392]
# Top-5 recommended IDs: [191, 388, 393, 161, 356]
# Hits in top-5: 2
# precision@5: 0.400
# --------------------------------------------------
# Relevant module IDs (ground truth): [304, 305, 312, 317, 318, 321, 322, 333, 334, 336, 340]
# Top-5 recommended IDs: [334, 361, 327, 332, 303]
# Hits in top-5: 1
# precision@5: 0.200
# --------------------------------------------------
# Relevant module IDs (ground truth): [159, 173, 177, 180, 193, 208, 290, 357, 397]
# Top-5 recommended IDs: [159, 193, 361, 207, 382]
# Hits in top-5: 2
# precision@5: 0.400
# --------------------------------------------------
# Average precision@5 over all students: 0.3333333333333333
# ============================================================
# Results for Student 1 (index 1):
# precision@5: 0.400
#    rank  module_id                module_name     score  \
# 0     1        191  De Kracht van de kunsten   0.539528
# 1     2        388                   Tekenen   0.339489
# 2     3        393  Ethiek & kritisch denken   0.253207
# 3     4        161    Proactieve zorgplanning  0.233174
# 4     5        356         The art of biology  0.225731
#
#                                         Motivation  \
# 0                  kunst, drama, ervan, fijn, vind
# 1                          tekenen, of, fijn, vind
# 2             kunst, kritisch denk, om, zingen, of
# 3  denk social, dansen, vermaken, of, toneelspelen
# 4                         kunst, tekenen, algemeen
#
#                                                                                                                                                                                         motivation_full
# 0                           Op basis van jouw antwoorden is een sterke match met jouw interesses. We zien dat **kunst, drama, ervan, fijn, vind** uit jouw antwoorden sterk overlappen met deze module.
# 1                      Tekenen  kan alsnog relevant zijn op basis van delen van jouw profiel. Je profiel vertelt over **tekenen, of, fijn, vind**, en deze interesses komen sterk terug in deze module.
# 2  Op basis van jouw antwoorden heeft een gematigde overlap met jouw interesses. Je profiel vertelt over **kunst, kritisch denk, om, zingen, of**, en deze interesses komen sterk terug in deze module.
# 3               Proactieve zorgplanning kan een interessante extra optie zijn. In jouw studentenprofiel noem je **denk social, dansen, vermaken, of, toneelspelen**, wat goed aansluit bij deze module.
# 4           The art of biology kan alsnog relevant zijn op basis van delen van jouw profiel. Je profiel vertelt over **kunst, tekenen, algemeen**, en deze interesses komen sterk terug in deze module.
# ============================================================
# Results for Student 2 (index 2):
# precision@5: 0.200
#    rank  module_id                                          module_name  \
# 0     1        334                               Artifical Intelligence
# 1     2        361                              Infectiepreventie (BML)
# 2     3        327  Analyseren van software en infrastructuur (1.3 BIM)
# 3     4        332            Software engineering, kwaliteit en testen
# 4     5        303                                  Operations Research
#
#       score                                     Motivation  \
# 0  0.315691                                  iets, ai, kun
# 1  0.303218         de, kritisch denk, denken, met, sterke
# 2  0.295800                                  software, kun
# 3  0.284021                                  software, aan
# 4  0.273788  techniek, met, software, techniek softwar, de
#
#                                                                                                                                                                             motivation_full
# 0                                                 Deze module kan een interessante extra optie zijn. In jouw studentenprofiel noem je **iets, ai, kun**, wat goed aansluit bij deze module.
# 1          Op basis van jouw antwoorden kan een interessante extra optie zijn. We zien dat **de, kritisch denk, denken, met, sterke** uit jouw antwoorden sterk overlappen met deze module.
# 2  Analyseren van software en infrastructuur (1.3 BIM) heeft een gematigde overlap met jouw interesses. We zien dat **software, kun** uit jouw antwoorden sterk overlappen met deze module.
# 3         Op basis van jouw antwoorden kan alsnog relevant zijn op basis van delen van jouw profiel. In jouw studentenprofiel noem je **software, aan**, wat goed aansluit bij deze module.
# 4  Operations Research heeft een gematigde overlap met jouw interesses. We zien dat **techniek, met, software, techniek softwar, de** uit jouw antwoorden sterk overlappen met deze module.
# ============================================================
# Results for Student 3 (index 3):
# precision@5: 0.400
#    rank  module_id                          module_name     score  \
# 0     1        159         Kennismaking met Psychologie  0.436239
# 1     2        193                               Gedrag  0.395505
# 2     3        361              Infectiepreventie (BML)  0.273995
# 3     4        207  Zorg in de langdurige hulpverlening  0.272277
# 4     5        382            Veranderen is Mensenwerk   0.269923
#
#                                    Motivation  \
# 0              dingen, mensen, doen, ik, over
# 1                dingen, persoonlijkheden, ik
# 2       dingen, kritisch denk, ik, ook, leren
# 3                                   begrijpen
# 4  begrijpen, wil, en, doen, persoonlijkheden
#
#                                                                                                                                                                                               motivation_full
# 0                                          Op basis van jouw antwoorden sluit goed aan bij jouw profiel. We zien dat **dingen, mensen, doen, ik, over** uit jouw antwoorden sterk overlappen met deze module.
# 1                                          Deze module heeft een gematigde overlap met jouw interesses. In jouw studentenprofiel noem je **dingen, persoonlijkheden, ik**, wat goed aansluit bij deze module.
# 2                               Infectiepreventie (BML) kan een interessante extra optie zijn. In jouw studentenprofiel noem je **dingen, kritisch denk, ik, ook, leren**, wat goed aansluit bij deze module.
# 3                               Op basis van jouw antwoorden kan alsnog relevant zijn op basis van delen van jouw profiel. In jouw studentenprofiel noem je **begrijpen**, wat goed aansluit bij deze module.
# 4  Op basis van jouw antwoorden heeft een gematigde overlap met jouw interesses. Je profiel vertelt over **begrijpen, wil, en, doen, persoonlijkheden**, en deze interesses komen sterk terug in deze module.

# %% [markdown]
# ## 2. New profiles created:

# %%
from helpers.notebook_pipelines.not_tuned_se_model import run_evaluation_multi as run_evaluation_multi_se
from helpers.notebook_pipelines.not_tuned_bow_model import run_evaluation_multi as run_evaluation_multi_bow
from helpers.functs.StudentProfile import StudentProfile
from IPython.display import display
import pandas as pd


# Our mocked student profiles
student1 = StudentProfile(
    current_study= "Economics",
    interests=[
        "Business",
        "Entrepreneurship",
        "Strategies",
        "Branding",
        "I am a real entrepreneur. I am especially interested in innovation and strategy. Also, how future developments influence economic growth and organizational success"
    ],
    wanted_study_credit_range=(15, 30),
    location_preference=["Den Bosch", "Breda", "Tilburg"],
    learning_goals=["Forward thinking", "Social skill", "I want to better understand the impact of modern technologies on business models"],
    level_preference=["NLQF5", "NLQF6"],
    preferred_language="NL",
    preferred_start_range="any"
)

student2 = StudentProfile(
    current_study= "Verpleegkunde",
    interests=[
        "Zorg",
        "Ziekenhuis",
        "Medisch",
        "Verpleegkunde",
        "Ik ben geïnteresseerd in verpleegkunde in het algemeen. Wel lijkt het me leuk als de module mij wat praktische ervaring geeft. Zoals werken in een ziekenhuisseting of met mensen die ik al echt kan helpen."
    ],
    wanted_study_credit_range=(15, 30),
    location_preference=["Den Bosch", "Breda", "Tilburg"],
    learning_goals=["Sociale vaardigheden", "Persoonlijke ontwikkeling", "Ik leren hoe ik beter kan anticiperen op bepaalde zorgbehoeften"],
    level_preference=["NLQF5", "NLQF6"],
    preferred_language="NL",
    preferred_start_range="any"
)

# Ground-truth relevant modules per student
matching_models_list = [
    [229, 272, 280, 279, 235, 380],          # student1
    [163, 160, 162, 161, 179]                # student2
]

students = [student1, student2,]

# %% [markdown]
# ## Running through SBERT model

# %%
all_results, avg_p_at_k = run_evaluation_multi_se(students, matching_models_list, top_n=5, k=5)

print("Average precision@5 over all students:", avg_p_at_k)

for idx, (student, result) in enumerate(zip(students, all_results), start=1):
    name = getattr(student, "name", f"Student {idx}")
    print("=" * 60)
    print(f"Results for {name} (index {idx}):")
    print(f"precision@5: {result['precision_at_k']:.3f}")

    old_width = pd.get_option("display.max_colwidth")
    pd.set_option("display.max_colwidth", None)
    display(result["recs"])
    pd.set_option("display.max_colwidth", old_width)
# Out:
# Relevant module IDs (ground truth): [229, 235, 272, 279, 280, 380]
# Top-5 recommended IDs: [364, 272, 279, 380, 372]
# Hits in top-5: 3
# precision@5: 0.600
# --------------------------------------------------
# Relevant module IDs (ground truth): [160, 161, 162, 163, 179]
# Top-5 recommended IDs: [162, 161, 171, 182, 316]
# Hits in top-5: 2
# precision@5: 0.400
# --------------------------------------------------
# Average precision@5 over all students: 0.5
# ============================================================
# Results for Student 1 (index 1):
# precision@5: 0.600
#    rank  module_id                                        module_name  \
# 0     1        364   Minor Biobased Technology & Business Development
# 1     2        272                         Duurzame Business Modellen
# 2     3        279                      Talent Acquisition & Branding
# 3     4        380                                      Game Changers
# 4     5        372  Innovation for sustainability \r\n(SDG in motion)
#
#       score  \
# 0  0.457200
# 1  0.456154
# 2  0.419838
# 3  0.411870
# 4  0.377812
#
#                                                                                                                                                                                            motivation_full
# 0  Minor Biobased Technology & Business Development is een sterke match met jouw interesses. We herkennen hierin wat je schreef: "Business Entrepreneurship Strategies Branding I am a real entrepreneur".
# 1                  Duurzame Business Modellen is een sterke match met jouw interesses. Met name jouw beschrijving "I am especially interested in innovation and strategy" komt sterk terug in deze module.
# 2                                         Deze module lijkt behoorlijk goed bij jou te passen. Dit sluit aan bij wat je vertelt: "Business Entrepreneurship Strategies Branding I am a real entrepreneur".
# 3                                                        Deze module is een sterke match met jouw interesses. We herkennen hierin wat je schreef: "I am especially interested in innovation and strategy".
# 4                                                Deze module heeft een gematigde overlap met jouw interesses. We herkennen hierin wat je schreef: "I am especially interested in innovation and strategy".
# ============================================================
# Results for Student 2 (index 2):
# precision@5: 0.400
#    rank  module_id                     module_name     score  \
# 0     1        162                 Rouw en verlies  0.623683
# 1     2        161         Proactieve zorgplanning  0.607219
# 2     3        171  Technologie in zorg en welzijn  0.595804
# 3     4        182      Werken vanuit je doelgroep  0.586893
# 4     5        316             Business Innovation  0.586525
#
#                                                                                                                                                                                                                              motivation_full
# 0  Op basis van jouw antwoorden sluit extreem goed aan bij jouw profiel. We herkennen hierin wat je schreef: "Sociale vaardigheden Persoonlijke ontwikkeling Ik leren hoe ik beter kan anticiperen op bepaalde zorgbehoeften Verpleegkunde".
# 1                          Op basis van jouw antwoorden is een bijna perfecte match met jouw interesses. We herkennen hierin wat je schreef: "Zorg Ziekenhuis Medisch Verpleegkunde Ik ben geïnteresseerd in verpleegkunde in het algemeen".
# 2                                Technologie in zorg en welzijn lijkt behoorlijk goed bij jou te passen. We herkennen hierin wat je schreef: "Zorg Ziekenhuis Medisch Verpleegkunde Ik ben geïnteresseerd in verpleegkunde in het algemeen".
# 3    Werken vanuit je doelgroep is een sterke match met jouw interesses. We herkennen hierin wat je schreef: "Sociale vaardigheden Persoonlijke ontwikkeling Ik leren hoe ik beter kan anticiperen op bepaalde zorgbehoeften Verpleegkunde".
# 4           Op basis van jouw antwoorden lijkt behoorlijk goed bij jou te passen. Met name jouw beschrijving "Zorg Ziekenhuis Medisch Verpleegkunde Ik ben geïnteresseerd in verpleegkunde in het algemeen" komt sterk terug in deze module.

# %% [markdown]
# ## Running through TF-IDF model

# %%
all_results, avg_p_at_k = run_evaluation_multi_bow(students, matching_models_list, top_n=5, k=5)

print("Average precision@5 over all students:", avg_p_at_k)

# Print model output for each student individually
for idx, (student, result) in enumerate(zip(students, all_results), start=1):
    name = getattr(student, "name", f"Student {idx}")
    print("=" * 60)
    print(f"Results for {name} (index {idx}):")
    print(f"precision@5: {result['precision_at_k']:.3f}")

    # Pandas settings for max width columns
    old_width = pd.get_option("display.max_colwidth")
    pd.set_option("display.max_colwidth", None)

    # Show updated recommendations
    display(result["recs"])

    # Restoring original pandas setting
    pd.set_option("display.max_colwidth", old_width)
# Out:
# (211, 12596)
# Relevant module IDs (ground truth): [229, 235, 272, 279, 280, 380]
# Top-5 recommended IDs: [229, 364, 224, 341, 347]
# Hits in top-5: 1
# precision@5: 0.200
# --------------------------------------------------
# Relevant module IDs (ground truth): [160, 161, 162, 163, 179]
# Top-5 recommended IDs: [163, 164, 161, 160, 176]
# Hits in top-5: 3
# precision@5: 0.600
# --------------------------------------------------
# Average precision@5 over all students: 0.4
# ============================================================
# Results for Student 1 (index 1):
# precision@5: 0.200
#    rank  module_id                                             module_name  \
# 0     1        229                       International Business Operations
# 1     2        364        Minor Biobased Technology & Business Development
# 2     3        224  Biobased Technology and Business Development. Zie ALST
# 3     4        341              Minor AquaCycle: Circular Water Technology
# 4     5        347              Minor AquaCycle: Circular Water Technology
#
#       score                                                       Motivation  \
# 0  0.627924                                          business, i, interested
# 1  0.512082        business, forward, busi model, technolog busi, interested
# 2  0.392440  business, technolog busi, forward, interested, entrepreneurship
# 3  0.290620                           forward, and, entrepreneur, am, social
# 4  0.290620                           forward, and, entrepreneur, am, social
#
#                                                                                                                                                                                                                motivation_full
# 0                                                                Deze module past heel sterk bij wat jij leuk vindt. Je profiel vertelt over **business, i, interested**, en deze interesses komen sterk terug in deze module.
# 1                             Deze module lijkt behoorlijk goed bij jou te passen. Je profiel vertelt over **business, forward, busi model, technolog busi, interested**, en deze interesses komen sterk terug in deze module.
# 2  Deze module kan alsnog relevant zijn op basis van delen van jouw profiel. Je profiel vertelt over **business, technolog busi, forward, interested, entrepreneurship**, en deze interesses komen sterk terug in deze module.
# 3                                Op basis van jouw antwoorden heeft een gematigde overlap met jouw interesses. In jouw studentenprofiel noem je **forward, and, entrepreneur, am, social**, wat goed aansluit bij deze module.
# 4                     Minor AquaCycle: Circular Water Technology heeft een gematigde overlap met jouw interesses. We zien dat **forward, and, entrepreneur, am, social** uit jouw antwoorden sterk overlappen met deze module.
# ============================================================
# Results for Student 2 (index 2):
# precision@5: 0.600
#    rank  module_id                                               module_name  \
# 0     1        163                                       Acuut complexe zorg
# 1     2        164                                       Kraam kind en jeugd
# 2     3        161                                   Proactieve zorgplanning
# 3     4        160                               Learning and working abroad
# 4     5        176  Technologie die ècht werkt: innovatie in zorg en welzijn
#
#       score                                   Motivation  \
# 0  0.554005                               ben, zorg, het
# 1  0.485504                                     ben, het
# 2  0.385687              leuk, ben, ziekenhuis, mij, het
# 3  0.333842  ben, person ontwikkel, wel, mij, praktische
# 4  0.323840                 de, zorg, module, zoals, het
#
#                                                                                                                                                                                                              motivation_full
# 0                                                              Op basis van jouw antwoorden lijkt behoorlijk goed bij jou te passen. In jouw studentenprofiel noem je **ben, zorg, het**, wat goed aansluit bij deze module.
# 1                                                                                Kraam kind en jeugd is een sterke match met jouw interesses. We zien dat **ben, het** uit jouw antwoorden sterk overlappen met deze module.
# 2                                               Op basis van jouw antwoorden kan een interessante extra optie zijn. In jouw studentenprofiel noem je **leuk, ben, ziekenhuis, mij, het**, wat goed aansluit bij deze module.
# 3                                       Learning and working abroad kan een interessante extra optie zijn. We zien dat **ben, person ontwikkel, wel, mij, praktische** uit jouw antwoorden sterk overlappen met deze module.
# 4  Technologie die ècht werkt: innovatie in zorg en welzijn kan alsnog relevant zijn op basis van delen van jouw profiel. We zien dat **de, zorg, module, zoals, het** uit jouw antwoorden sterk overlappen met deze module.
