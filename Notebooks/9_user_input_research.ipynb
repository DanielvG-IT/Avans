# %% [markdown]
# # User Input Research
# In the evaluation of our report, we discussed the differences between the final performance of both models. However, during our investigation, we suspected that we unintentionally formulated the user inputs to facilitate their use in a TF-IDF model.
#
# Therefore, we will compare the models again, but this time with modified and new user inputs.

# %% [markdown]
# ## 1. Previously Used Student Profiles Adjusted
# Here we will adjust the 3 already known user profile to contain more natural data. The data that they contained earlier cannot be expected from a real user, they don't write in such concise manner. Especially when writing about their personal interests.

# %%
from helpers.notebook_pipelines.not_tuned_se_model import run_evaluation_multi as run_evaluation_multi_se
from helpers.notebook_pipelines.not_tuned_bow_model import run_evaluation_multi as run_evaluation_multi_bow
from helpers.functs.StudentProfile import StudentProfile
from IPython.display import display
import pandas as pd


# Our mocked student profiles
student1 = StudentProfile(
    current_study= "Kunst & Onderzoek",
    interests=[
        "Tekenen",
        "Animatie",
        "Kunst",
        "Drama",
        "Ik hou ervan om mensen te vermaken. Dit doe ik het liefst door bijvoorbeeld te dansen, te zingen of toneelspelen. In het algemeen vind ik het fijn om creatief bezig te zijn. Ik ben graag onder de mensen."
    ],
    wanted_study_credit_range=(15, 30),
    location_preference=["Den Bosch", "Breda", "Tilburg"],
    learning_goals=["Kritisch denken", "Sociale vaardigheden", "Zelfverzekerdheid", "Ik wil o.a. leren hoe ik betere illustraties kan maken zowel analoog als digitaal."],
    level_preference=["NLQF5", "NLQF6"],
    preferred_language="NL",
    preferred_start_range="any"
)

student2 = StudentProfile(
    current_study= "Informatica",
    interests=[
        "Programmeren",
        "AI",
        "Coderen",
        "Techniek",
        "Software",
        "Ik heb werken met computers en techniek van jongs af aan al interessant gevonden. Kunstmatige intelligentie is nu ook zeker iets dat me interesseert, zeker met de sterke opkomst hiervan. Zo kun je denken aan machine learning, deep learning, etc. Ik wil me vooral bezighouden met software."
    ],
    wanted_study_credit_range=(15, 30),
    location_preference=["Den Bosch", "Breda", "Tilburg"],
    learning_goals=["Kritisch denken", "Technische Vaardigheden", "Eén van de dingen die ik wil leren is het toepassen van mijn kennis in de praktijk"],
    level_preference=["NLQF5", "NLQF6"],
    preferred_language="NL",
    preferred_start_range="any"
)

student3 = StudentProfile(
    current_study= "Psychologie",
    interests=[
        "Mensen",
        "Emoties",
        "Gedrag",
        "Psychologie",
        "Ik wil graag weten waarom mensen bepaalde dingen doen; ik wil mensen hun gedrag kunnen begrijpen. Naast hun gedrag wil ik ook leren over, persoonlijkheden en emoties. Graag wil ik mensen hun welzijn kunnen bevorderen met het gebruik van psychologische kennis."
    ],
    wanted_study_credit_range=(15, 30),
    location_preference=["Den Bosch", "Breda", "Tilburg"],
    learning_goals=["Kritisch denken", "Sociale Vaardigheden", "Ik wil leren hoe ik mensen en hun gedrag beter kan analyseren"],
    level_preference=["NLQF5", "NLQF6"],
    preferred_language="NL",
    preferred_start_range="any"
)

# Ground-truth relevant modules per student
matching_models_list = [
    [388, 392, 191, 385, 386, 379, 389, 377, 391, 233],          # student1
    [304, 305, 312, 317, 318, 322, 321, 334, 336, 340, 333],     # student2
    [159, 290, 397, 180, 177, 208, 173, 193, 357]                # student3
]

students = [student1, student2, student3]

# %% [markdown]
# ## Running through SBERT model

# %%
all_results, avg_p_at_k = run_evaluation_multi_se(students, matching_models_list, top_n=5, k=5)

print("Average precision@5 over all students:", avg_p_at_k)

for idx, (student, result) in enumerate(zip(students, all_results), start=1):
    name = getattr(student, "name", f"Student {idx}")
    print("=" * 60)
    print(f"Results for {name} (index {idx}):")
    print(f"precision@5: {result['precision_at_k']:.3f}")

    old_width = pd.get_option("display.max_colwidth")
    pd.set_option("display.max_colwidth", None)
    display(result["recs"])
    pd.set_option("display.max_colwidth", old_width)
# Out:
# Relevant module IDs (ground truth): [191, 233, 377, 379, 385, 386, 388, 389, 391, 392]
# Top-5 recommended IDs: [191, 391, 233, 386, 384]
# Hits in top-5: 4
# precision@5: 0.800
# --------------------------------------------------
# Relevant module IDs (ground truth): [304, 305, 312, 317, 318, 321, 322, 333, 334, 336, 340]
# Top-5 recommended IDs: [333, 366, 171, 340, 226]
# Hits in top-5: 2
# precision@5: 0.400
# --------------------------------------------------
# Relevant module IDs (ground truth): [159, 173, 177, 180, 193, 208, 290, 357, 397]
# Top-5 recommended IDs: [159, 173, 197, 391, 177]
# Hits in top-5: 3
# precision@5: 0.600
# --------------------------------------------------
# Average precision@5 over all students: 0.6000000000000001
# ============================================================
# Results for Student 1 (index 1):
# precision@5: 0.800
#    rank  module_id  \
# 0     1        191
# 1     2        391
# 2     3        233
# 3     4        386
# 4     5        384
#
#                                                    module_name     score  \
# 0                                    De Kracht van de kunsten   0.687917
# 1                     Art & Humanity (nieuwe naam formuleren)   0.667841
# 2  Artistiek ondernemerschap voor kunst, design en performance  0.600675
# 3                                               Graphic Novel   0.599407
# 4                                Development for Storytelling   0.594137
#
#                                                                                                                                                                                                      motivation_full
# 0                   De Kracht van de kunsten  sluit extreem goed aan bij jouw profiel. Met name jouw beschrijving "Tekenen Animatie Kunst Drama Ik hou ervan om mensen te vermaken" komt sterk terug in deze module.
# 1                                 Deze module sluit extreem goed aan bij jouw profiel. Met name jouw beschrijving "Tekenen Animatie Kunst Drama Ik hou ervan om mensen te vermaken" komt sterk terug in deze module.
# 2  Op basis van jouw antwoorden is een bijna perfecte match met jouw interesses. Met name jouw beschrijving "leren hoe ik betere illustraties kan maken zowel analoog als digitaal" komt sterk terug in deze module.
# 3                                   Deze module sluit goed aan bij jouw profiel. Je profiel benadrukt vooral "Dit doe ik het liefst door bijvoorbeeld te dansen, te zingen of toneelspelen", wat hier goed bij past.
# 4                                 Op basis van jouw antwoorden is een sterke match met jouw interesses. We herkennen hierin wat je schreef: "leren hoe ik betere illustraties kan maken zowel analoog als digitaal".
# ============================================================
# Results for Student 2 (index 2):
# precision@5: 0.400
#    rank  module_id                          module_name     score  \
# 0     1        333  Smart Industry & Internet of Things  0.717085
# 1     2        366            Didactiek voor N&G en N&T  0.680460
# 2     3        171       Technologie in zorg en welzijn  0.671237
# 3     4        340                        AI Translator  0.669332
# 4     5        226    Digital Nomads NLQF 6, 30 + 15 EC  0.663012
#
#                                                                                                                                                                                                                                                    motivation_full
# 0                         Op basis van jouw antwoorden is een bijna perfecte match met jouw interesses. Dit sluit aan bij wat je vertelt: "Kritisch denken Technische Vaardigheden Eén van de dingen die ik wil leren is het toepassen van mijn kennis in de ...".
# 1                         Deze module sluit extreem goed aan bij jouw profiel. Met name jouw beschrijving "Kritisch denken Technische Vaardigheden Eén van de dingen die ik wil leren is het toepassen van mijn kennis in de ..." komt sterk terug in deze module.
# 2                       Technologie in zorg en welzijn is een bijna perfecte match met jouw interesses. Dit sluit aan bij wat je vertelt: "Kritisch denken Technische Vaardigheden Eén van de dingen die ik wil leren is het toepassen van mijn kennis in de ...".
# 3                                           AI Translator is een bijna perfecte match met jouw interesses. Vooral omdat je aangeeft: "Programmeren AI Coderen Techniek Software Ik heb werken met computers en techniek van jongs af aan al interessant gevonden".
# 4  Op basis van jouw antwoorden is een bijna perfecte match met jouw interesses. Je profiel benadrukt vooral "Programmeren AI Coderen Techniek Software Ik heb werken met computers en techniek van jongs af aan al interessant gevonden", wat hier goed bij past.
# ============================================================
# Results for Student 3 (index 3):
# precision@5: 0.600
#    rank  module_id                               module_name     score  \
# 0     1        159              Kennismaking met Psychologie  0.641677
# 1     2        173                   Langer thuis in de wijk  0.611109
# 2     3        197                 Werken in gedwongen kader  0.563634
# 3     4        391  Art & Humanity (nieuwe naam formuleren)   0.559185
# 4     5        177                Patronen doorbreken: basis  0.534506
#
#                                                                                                                                                                                                                                                                motivation_full
# 0                                                                      Deze module sluit extreem goed aan bij jouw profiel. Je profiel benadrukt vooral "Graag wil ik mensen hun welzijn kunnen bevorderen met het gebruik van psychologische kennis", wat hier goed bij past.
# 1                                                                                       Deze module past heel sterk bij wat jij leuk vindt. We herkennen hierin wat je schreef: "Graag wil ik mensen hun welzijn kunnen bevorderen met het gebruik van psychologische kennis".
# 2                                                            Op basis van jouw antwoorden is een sterke match met jouw interesses. Vooral omdat je aangeeft: "Kritisch denken Sociale Vaardigheden Ik wil leren hoe ik mensen en hun gedrag beter kan analyseren Psychologie".
# 3  Art & Humanity (nieuwe naam formuleren)  is een sterke match met jouw interesses. Je profiel benadrukt vooral "Mensen Emoties Gedrag Psychologie Ik wil graag weten waarom mensen bepaalde dingen doen; ik wil mensen hun gedrag kunnen begrijpen", wat hier goed bij past.
# 4                                                                      Deze module lijkt behoorlijk goed bij jou te passen. Je profiel benadrukt vooral "Graag wil ik mensen hun welzijn kunnen bevorderen met het gebruik van psychologische kennis", wat hier goed bij past.

# %% [markdown]
# ## Running through TF-IDF model

# %%
all_results, avg_p_at_k = run_evaluation_multi_bow(students, matching_models_list, top_n=5, k=5)

print("Average precision@5 over all students:", avg_p_at_k)

# Print model output for each student individually
for idx, (student, result) in enumerate(zip(students, all_results), start=1):
    name = getattr(student, "name", f"Student {idx}")
    print("=" * 60)
    print(f"Results for {name} (index {idx}):")
    print(f"precision@5: {result['precision_at_k']:.3f}")

    # Pandas settings for max width columns
    old_width = pd.get_option("display.max_colwidth")
    pd.set_option("display.max_colwidth", None)

    # Show updated recommendations
    display(result["recs"])

    # Restoring original pandas setting
    pd.set_option("display.max_colwidth", old_width)
# Out:
# (211, 12596)
# Relevant module IDs (ground truth): [191, 233, 377, 379, 385, 386, 388, 389, 391, 392]
# Top-5 recommended IDs: [191, 388, 393, 161, 356]
# Hits in top-5: 2
# precision@5: 0.400
# --------------------------------------------------
# Relevant module IDs (ground truth): [304, 305, 312, 317, 318, 321, 322, 333, 334, 336, 340]
# Top-5 recommended IDs: [334, 361, 327, 332, 303]
# Hits in top-5: 1
# precision@5: 0.200
# --------------------------------------------------
# Relevant module IDs (ground truth): [159, 173, 177, 180, 193, 208, 290, 357, 397]
# Top-5 recommended IDs: [159, 193, 361, 207, 382]
# Hits in top-5: 2
# precision@5: 0.400
# --------------------------------------------------
# Average precision@5 over all students: 0.3333333333333333
# ============================================================
# Results for Student 1 (index 1):
# precision@5: 0.400
#    rank  module_id                module_name     score  \
# 0     1        191  De Kracht van de kunsten   0.539528
# 1     2        388                   Tekenen   0.339489
# 2     3        393  Ethiek & kritisch denken   0.253207
# 3     4        161    Proactieve zorgplanning  0.233174
# 4     5        356         The art of biology  0.225731
#
#                                         Motivation  \
# 0                  kunst, drama, ervan, fijn, vind
# 1                          tekenen, of, fijn, vind
# 2             kunst, kritisch denk, om, zingen, of
# 3  denk social, dansen, vermaken, of, toneelspelen
# 4                         kunst, tekenen, algemeen
#
#                                                                                                                                                                                                   motivation_full
# 0                                     Op basis van jouw antwoorden lijkt behoorlijk goed bij jou te passen. We zien dat **kunst, drama, ervan, fijn, vind** uit jouw antwoorden sterk overlappen met deze module.
# 1                                             Tekenen  heeft een gematigde overlap met jouw interesses. Je profiel vertelt over **tekenen, of, fijn, vind**, en deze interesses komen sterk terug in deze module.
# 2  Ethiek & kritisch denken  kan alsnog relevant zijn op basis van delen van jouw profiel. Je profiel vertelt over **kunst, kritisch denk, om, zingen, of**, en deze interesses komen sterk terug in deze module.
# 3                       Op basis van jouw antwoorden kan een interessante extra optie zijn. We zien dat **denk social, dansen, vermaken, of, toneelspelen** uit jouw antwoorden sterk overlappen met deze module.
# 4                                 The art of biology kan alsnog relevant zijn op basis van delen van jouw profiel. We zien dat **kunst, tekenen, algemeen** uit jouw antwoorden sterk overlappen met deze module.
# ============================================================
# Results for Student 2 (index 2):
# precision@5: 0.200
#    rank  module_id                                          module_name  \
# 0     1        334                               Artifical Intelligence
# 1     2        361                              Infectiepreventie (BML)
# 2     3        327  Analyseren van software en infrastructuur (1.3 BIM)
# 3     4        332            Software engineering, kwaliteit en testen
# 4     5        303                                  Operations Research
#
#       score                                     Motivation  \
# 0  0.315691                                  iets, ai, kun
# 1  0.303218         de, kritisch denk, denken, met, sterke
# 2  0.295800                                  software, kun
# 3  0.284021                                  software, aan
# 4  0.273788  techniek, met, software, techniek softwar, de
#
#                                                                                                                                                                                             motivation_full
# 0                                                      Artifical Intelligence kan een interessante extra optie zijn. In jouw studentenprofiel noem je **iets, ai, kun**, wat goed aansluit bij deze module.
# 1   Op basis van jouw antwoorden kan alsnog relevant zijn op basis van delen van jouw profiel. We zien dat **de, kritisch denk, denken, met, sterke** uit jouw antwoorden sterk overlappen met deze module.
# 2     Analyseren van software en infrastructuur (1.3 BIM) kan alsnog relevant zijn op basis van delen van jouw profiel. We zien dat **software, kun** uit jouw antwoorden sterk overlappen met deze module.
# 3               Software engineering, kwaliteit en testen kan alsnog relevant zijn op basis van delen van jouw profiel. We zien dat **software, aan** uit jouw antwoorden sterk overlappen met deze module.
# 4  Operations Research kan alsnog relevant zijn op basis van delen van jouw profiel. In jouw studentenprofiel noem je **techniek, met, software, techniek softwar, de**, wat goed aansluit bij deze module.
# ============================================================
# Results for Student 3 (index 3):
# precision@5: 0.400
#    rank  module_id                          module_name     score  \
# 0     1        159         Kennismaking met Psychologie  0.436239
# 1     2        193                               Gedrag  0.395505
# 2     3        361              Infectiepreventie (BML)  0.273995
# 3     4        207  Zorg in de langdurige hulpverlening  0.272277
# 4     5        382            Veranderen is Mensenwerk   0.269923
#
#                                    Motivation  \
# 0              dingen, mensen, doen, ik, over
# 1                dingen, persoonlijkheden, ik
# 2       dingen, kritisch denk, ik, ook, leren
# 3                                   begrijpen
# 4  begrijpen, wil, en, doen, persoonlijkheden
#
#                                                                                                                                                                                   motivation_full
# 0                  Op basis van jouw antwoorden sluit goed aan bij jouw profiel. Je profiel vertelt over **dingen, mensen, doen, ik, over**, en deze interesses komen sterk terug in deze module.
# 1                    Deze module kan alsnog relevant zijn op basis van delen van jouw profiel. We zien dat **dingen, persoonlijkheden, ik** uit jouw antwoorden sterk overlappen met deze module.
# 2              Op basis van jouw antwoorden kan een interessante extra optie zijn. In jouw studentenprofiel noem je **dingen, kritisch denk, ik, ook, leren**, wat goed aansluit bij deze module.
# 3                                      Zorg in de langdurige hulpverlening kan een interessante extra optie zijn. We zien dat **begrijpen** uit jouw antwoorden sterk overlappen met deze module.
# 4  Op basis van jouw antwoorden heeft een gematigde overlap met jouw interesses. We zien dat **begrijpen, wil, en, doen, persoonlijkheden** uit jouw antwoorden sterk overlappen met deze module.

# %% [markdown]
# ## 2. New profiles created:

# %%
from helpers.notebook_pipelines.not_tuned_se_model import run_evaluation_multi as run_evaluation_multi_se
from helpers.notebook_pipelines.not_tuned_bow_model import run_evaluation_multi as run_evaluation_multi_bow
from helpers.functs.StudentProfile import StudentProfile
from IPython.display import display
import pandas as pd


# Our mocked student profiles
student1 = StudentProfile(
    current_study= "Economics",
    interests=[
        "Business",
        "Entrepreneurship",
        "Strategies",
        "Branding",
        "I am a real entrepreneur. I am especially interested in how innovation, strategy, and future developments influence economic growth and organizational success"
    ],
    wanted_study_credit_range=(15, 30),
    location_preference=["Den Bosch", "Breda", "Tilburg"],
    learning_goals=["Forward thinking", "Social skill", "I want to better understand the impact of modern technologies on business models"],
    level_preference=["NLQF5", "NLQF6"],
    preferred_language="NL",
    preferred_start_range="any"
)

student2 = StudentProfile(
    current_study= "Verpleegkunde, Mens en Techniek",
    interests=[
        "Zorg",
        "Gezondheid",
        "Medisch",
        "Verpleegkunde",
        "Ik ben erg geïnteresseerd in verpleegkunde en hoop ook later in een ziekenhuis omgeving te kunnen werken. Daarom wil ik ook meer praktische ervaring op doen passend bij mijn studie verpleegkunde met de module die ik kies."
    ],
    wanted_study_credit_range=(15, 30),
    location_preference=["Den Bosch", "Breda", "Tilburg"],
    learning_goals=["Sociale vaardigheden", "Persoonlijke ontwikkeling", "Ik leren hoe ik beter kan anticiperen op bepaalde zorgbehoeften"],
    level_preference=["NLQF5", "NLQF6"],
    preferred_language="NL",
    preferred_start_range="any"
)

# Ground-truth relevant modules per student
matching_models_list = [
    [229, 272, 280, 279, 235, 380],          # student1
    [160],     # student2
]

students = [student1, student2,]

# %% [markdown]
# ## Running through SBERT model

# %%
all_results, avg_p_at_k = run_evaluation_multi_se(students, matching_models_list, top_n=5, k=5)

print("Average precision@5 over all students:", avg_p_at_k)

for idx, (student, result) in enumerate(zip(students, all_results), start=1):
    name = getattr(student, "name", f"Student {idx}")
    print("=" * 60)
    print(f"Results for {name} (index {idx}):")
    print(f"precision@5: {result['precision_at_k']:.3f}")

    old_width = pd.get_option("display.max_colwidth")
    pd.set_option("display.max_colwidth", None)
    display(result["recs"])
    pd.set_option("display.max_colwidth", old_width)
# Out:
# Relevant module IDs (ground truth): [229, 235, 272, 279, 280, 380]
# Top-5 recommended IDs: [364, 272, 279, 380, 372]
# Hits in top-5: 3
# precision@5: 0.600
# --------------------------------------------------
# Relevant module IDs (ground truth): [160]
# Top-5 recommended IDs: [316, 340, 182, 162, 171]
# Hits in top-5: 0
# precision@5: 0.000
# --------------------------------------------------
# Average precision@5 over all students: 0.3
# ============================================================
# Results for Student 1 (index 1):
# precision@5: 0.600
#    rank  module_id                                        module_name  \
# 0     1        364   Minor Biobased Technology & Business Development
# 1     2        272                         Duurzame Business Modellen
# 2     3        279                      Talent Acquisition & Branding
# 3     4        380                                      Game Changers
# 4     5        372  Innovation for sustainability \r\n(SDG in motion)
#
#       score  \
# 0  0.454051
# 1  0.452822
# 2  0.423534
# 3  0.412076
# 4  0.378641
#
#                                                                                                                                                                                                                                                                                         motivation_full
# 0                                                                                                                             Op basis van jouw antwoorden is een sterke match met jouw interesses. Vooral omdat je aangeeft: "Business Entrepreneurship Strategies Branding I am a real entrepreneur".
# 1  Op basis van jouw antwoorden is een sterke match met jouw interesses. Met name jouw beschrijving "I am especially interested in how innovation, strategy, and future developments influence economic growth and organizational success Forward thinking Social ..." komt sterk terug in deze module.
# 2                                                                                                                             Op basis van jouw antwoorden sluit goed aan bij jouw profiel. Dit sluit aan bij wat je vertelt: "Business Entrepreneurship Strategies Branding I am a real entrepreneur".
# 3                           Op basis van jouw antwoorden lijkt behoorlijk goed bij jou te passen. Dit sluit aan bij wat je vertelt: "I am especially interested in how innovation, strategy, and future developments influence economic growth and organizational success Forward thinking Social ...".
# 4                                            Deze module heeft een gematigde overlap met jouw interesses. Vooral omdat je aangeeft: "I am especially interested in how innovation, strategy, and future developments influence economic growth and organizational success Forward thinking Social ...".
# ============================================================
# Results for Student 2 (index 2):
# precision@5: 0.000
#    rank  module_id                     module_name     score  \
# 0     1        316             Business Innovation  0.647046
# 1     2        340                   AI Translator  0.641496
# 2     3        182      Werken vanuit je doelgroep  0.639412
# 3     4        162                 Rouw en verlies  0.638882
# 4     5        171  Technologie in zorg en welzijn  0.630825
#
#                                                                                                                                                                                                                                                                      motivation_full
# 0                             Deze module past heel sterk bij wat jij leuk vindt. Je profiel benadrukt vooral "Zorg Gezondheid Medisch Verpleegkunde Ik ben erg geïnteresseerd in verpleegkunde en hoop ook later in een ziekenhuis omgeving te kunnen ...", wat hier goed bij past.
# 1  Op basis van jouw antwoorden past heel sterk bij wat jij leuk vindt. Met name jouw beschrijving "Sociale vaardigheden Persoonlijke ontwikkeling Ik leren hoe ik beter kan anticiperen op bepaalde zorgbehoeften Verpleegkunde, Mens en Techniek" komt sterk terug in deze module.
# 2                                    Werken vanuit je doelgroep sluit extreem goed aan bij jouw profiel. Vooral omdat je aangeeft: "Sociale vaardigheden Persoonlijke ontwikkeling Ik leren hoe ik beter kan anticiperen op bepaalde zorgbehoeften Verpleegkunde, Mens en Techniek".
# 3                     Op basis van jouw antwoorden is een bijna perfecte match met jouw interesses. Dit sluit aan bij wat je vertelt: "Zorg Gezondheid Medisch Verpleegkunde Ik ben erg geïnteresseerd in verpleegkunde en hoop ook later in een ziekenhuis omgeving te kunnen ...".
# 4  Op basis van jouw antwoorden past heel sterk bij wat jij leuk vindt. Met name jouw beschrijving "Sociale vaardigheden Persoonlijke ontwikkeling Ik leren hoe ik beter kan anticiperen op bepaalde zorgbehoeften Verpleegkunde, Mens en Techniek" komt sterk terug in deze module.

# %% [markdown]
# ## Running through TF-IDF model

# %%
all_results, avg_p_at_k = run_evaluation_multi_bow(students, matching_models_list, top_n=5, k=5)

print("Average precision@5 over all students:", avg_p_at_k)

# Print model output for each student individually
for idx, (student, result) in enumerate(zip(students, all_results), start=1):
    name = getattr(student, "name", f"Student {idx}")
    print("=" * 60)
    print(f"Results for {name} (index {idx}):")
    print(f"precision@5: {result['precision_at_k']:.3f}")

    # Pandas settings for max width columns
    old_width = pd.get_option("display.max_colwidth")
    pd.set_option("display.max_colwidth", None)

    # Show updated recommendations
    display(result["recs"])

    # Restoring original pandas setting
    pd.set_option("display.max_colwidth", old_width)
# Out:
# (211, 12596)
# Relevant module IDs (ground truth): [229, 235, 272, 279, 280, 380]
# Top-5 recommended IDs: [229, 364, 224, 341, 347]
# Hits in top-5: 1
# precision@5: 0.200
# --------------------------------------------------
# Relevant module IDs (ground truth): [160]
# Top-5 recommended IDs: [163, 164, 160, 161, 259]
# Hits in top-5: 1
# precision@5: 0.200
# --------------------------------------------------
# Average precision@5 over all students: 0.2
# ============================================================
# Results for Student 1 (index 1):
# precision@5: 0.200
#    rank  module_id                                             module_name  \
# 0     1        229                       International Business Operations
# 1     2        364        Minor Biobased Technology & Business Development
# 2     3        224  Biobased Technology and Business Development. Zie ALST
# 3     4        341              Minor AquaCycle: Circular Water Technology
# 4     5        347              Minor AquaCycle: Circular Water Technology
#
#       score                                                       Motivation  \
# 0  0.635524                                          business, i, especially
# 1  0.518280        business, forward, busi model, technolog busi, especially
# 2  0.397190  business, technolog busi, forward, especially, entrepreneurship
# 3  0.270945                    forward, and, entrepreneur, social, influence
# 4  0.270945                    forward, and, entrepreneur, social, influence
#
#                                                                                                                                                                                                              motivation_full
# 0                                                              Deze module past heel sterk bij wat jij leuk vindt. Je profiel vertelt over **business, i, especially**, en deze interesses komen sterk terug in deze module.
# 1  Minor Biobased Technology & Business Development lijkt behoorlijk goed bij jou te passen. We zien dat **business, forward, busi model, technolog busi, especially** uit jouw antwoorden sterk overlappen met deze module.
# 2                                Deze module kan een interessante extra optie zijn. In jouw studentenprofiel noem je **business, technolog busi, forward, especially, entrepreneurship**, wat goed aansluit bij deze module.
# 3          Minor AquaCycle: Circular Water Technology kan een interessante extra optie zijn. Je profiel vertelt over **forward, and, entrepreneur, social, influence**, en deze interesses komen sterk terug in deze module.
# 4                                                  Deze module kan een interessante extra optie zijn. In jouw studentenprofiel noem je **forward, and, entrepreneur, social, influence**, wat goed aansluit bij deze module.
# ============================================================
# Results for Student 2 (index 2):
# precision@5: 0.200
#    rank  module_id  \
# 0     1        163
# 1     2        164
# 2     3        160
# 3     4        161
# 4     5        259
#
#                                                   module_name     score  \
# 0                                         Acuut complexe zorg  0.651650
# 1                                         Kraam kind en jeugd  0.586248
# 2                                 Learning and working abroad  0.366992
# 3                                     Proactieve zorgplanning  0.320357
# 4  Module 3.4 Duurzaam gebouwde omgeving - Gezondheid en zorg  0.274092
#
#                                             Motivation  \
# 0                                       doen, zorg, te
# 1                                             doen, te
# 2              doen, person ontwikkel, in, werken, wil
# 3  doen, verpleegkund modul, verpleegkunde, werken, te
# 4               gezondheid, omgev werk, zorg, en, hoop
#
#                                                                                                                                                                                                        motivation_full
# 0                                                         Acuut complexe zorg past heel sterk bij wat jij leuk vindt. Je profiel vertelt over **doen, zorg, te**, en deze interesses komen sterk terug in deze module.
# 1                                                                               Kraam kind en jeugd sluit goed aan bij jouw profiel. In jouw studentenprofiel noem je **doen, te**, wat goed aansluit bij deze module.
# 2             Op basis van jouw antwoorden kan alsnog relevant zijn op basis van delen van jouw profiel. We zien dat **doen, person ontwikkel, in, werken, wil** uit jouw antwoorden sterk overlappen met deze module.
# 3                          Proactieve zorgplanning kan een interessante extra optie zijn. In jouw studentenprofiel noem je **doen, verpleegkund modul, verpleegkunde, werken, te**, wat goed aansluit bij deze module.
# 4  Op basis van jouw antwoorden kan alsnog relevant zijn op basis van delen van jouw profiel. Je profiel vertelt over **gezondheid, omgev werk, zorg, en, hoop**, en deze interesses komen sterk terug in deze module.
