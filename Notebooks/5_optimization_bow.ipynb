# %% [markdown]
# # Optimization BOW model
# Here a list of things we tuned for our model, eventually a new py file of the model has been made named "optimized_bow.py"

# %% [markdown]
# The list:
# - Dimensionality reduction final dimension size
# - TF-IDF N-gram range + starting max features
#
# This has been explained in detail inside of our report
