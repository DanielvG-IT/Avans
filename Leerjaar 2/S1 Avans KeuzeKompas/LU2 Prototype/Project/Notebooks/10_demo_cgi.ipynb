# %% [markdown]
# # Finale demo

# %% [markdown]
# ## 1. Setting up 5 different student profiles with different interests

# %%
from helpers.notebook_pipelines.yes_tuned_se_model import run_evaluation_multi as run_evaluation_multi_se
from helpers.notebook_pipelines.yes_tuned_bow_model import run_evaluation_multi as run_evaluation_multi_bow
from helpers.functs.StudentProfile import StudentProfile
from IPython.display import display
import pandas as pd


# Our mocked student profiles
student1 = StudentProfile(
    current_study= "Kunst & Onderzoek",
    interests=[
        "Tekenen",
        "Animatie",
        "Kunst",
        "Drama",
        "Ik hou ervan om mensen te vermaken. Dit doe ik het liefst door bijvoorbeeld te dansen, te zingen of toneelspelen. In het algemeen vind ik het fijn om creatief bezig te zijn. Ik ben graag onder de mensen."
    ],
    wanted_study_credit_range=(15, 30),
    location_preference=["Den Bosch", "Breda", "Tilburg"],
    learning_goals=["Kritisch denken", "Sociale vaardigheden", "Zelfverzekerdheid", "Ik wil o.a. leren hoe ik betere illustraties kan maken zowel analoog als digitaal."],
    level_preference=["NLQF5", "NLQF6"],
    preferred_language="NL",
    preferred_start_range="any"
)

student2 = StudentProfile(
    current_study= "Informatica",
    interests=[
        "Programmeren",
        "AI",
        "Coderen",
        "Techniek",
        "Software",
        "Ik heb werken met computers en techniek van jongs af aan al interessant gevonden. Kunstmatige intelligentie is nu ook zeker iets dat me interesseert, zeker met de sterke opkomst hiervan. Zo kun je denken aan machine learning, deep learning, etc. Ik wil me vooral bezighouden met software."
    ],
    wanted_study_credit_range=(15, 30),
    location_preference=["Den Bosch", "Breda", "Tilburg"],
    learning_goals=["Kritisch denken", "Technische Vaardigheden", "Eén van de dingen die ik wil leren is het toepassen van mijn kennis in de praktijk"],
    level_preference=["NLQF5", "NLQF6"],
    preferred_language="NL",
    preferred_start_range="any"
)

student3 = StudentProfile(
    current_study= "Psychologie",
    interests=[
        "Mensen",
        "Emoties",
        "Gedrag",
        "Psychologie",
        "Ik wil graag weten waarom mensen bepaalde dingen doen; ik wil mensen hun gedrag kunnen begrijpen. Naast hun gedrag wil ik ook leren over, persoonlijkheden en emoties. Graag wil ik mensen hun welzijn kunnen bevorderen met het gebruik van psychologische kennis."
    ],
    wanted_study_credit_range=(15, 30),
    location_preference=["Den Bosch", "Breda", "Tilburg"],
    learning_goals=["Kritisch denken", "Sociale Vaardigheden", "Ik wil leren hoe ik mensen en hun gedrag beter kan analyseren"],
    level_preference=["NLQF5", "NLQF6"],
    preferred_language="NL",
    preferred_start_range="any"
)

student4 = StudentProfile(
    current_study= "Economics",
    interests=[
        "Business",
        "Entrepreneurship",
        "Strategies",
        "Branding",
        "I am a real entrepreneur. I am especially interested in innovation and strategy. Also, how future developments influence economic growth and organizational success"
    ],
    wanted_study_credit_range=(15, 30),
    location_preference=["Den Bosch", "Breda", "Tilburg"],
    learning_goals=["Forward thinking", "Social skill", "I want to better understand the impact of modern technologies on business models"],
    level_preference=["NLQF5", "NLQF6"],
    preferred_language="NL",
    preferred_start_range="any"
)

student5 = StudentProfile(
    current_study= "Verpleegkunde",
    interests=[
        "Zorg",
        "Ziekenhuis",
        "Medisch",
        "Verpleegkunde",
        "Ik ben geïnteresseerd in verpleegkunde in het algemeen. Wel lijkt het me leuk als de module mij wat praktische ervaring geeft. Zoals werken in een ziekenhuisseting of met mensen die ik al echt kan helpen."
    ],
    wanted_study_credit_range=(15, 30),
    location_preference=["Den Bosch", "Breda", "Tilburg"],
    learning_goals=["Sociale vaardigheden", "Persoonlijke ontwikkeling", "Ik leren hoe het is om te werken in een ziekenhuisseting"],
    level_preference=["NLQF5", "NLQF6"],
    preferred_language="NL",
    preferred_start_range="any"
)

# Ground-truth relevant modules per student
matching_models_list = [
    [388, 191, 385, 379, 389, 377, 233, 375,391, 387],                     # student1
    [304, 305, 312, 317, 318, 322, 321, 334, 336, 340, 333],               # student2
    [159, 290, 397, 180, 177, 208, 173, 193, 357],                         # student3
    [229, 280, 279, 235, 380, 235, 237, 381],                              # student4
    [163, 160, 162, 161, 179]                                              # student5
]

students = [student1, student2, student3, student4, student5]

# %% [markdown]
# ## 2. Running them through our optimized SBERT model

# %%
all_results, avg_p_at_k = run_evaluation_multi_se(students, matching_models_list, top_n=5, k=5)

print("Average precision@5 over all students:", avg_p_at_k)

for idx, (student, result) in enumerate(zip(students, all_results), start=1):
    name = getattr(student, "name", f"Student {idx}")
    print("=" * 60)
    print(f"Results for {name} (index {idx}):")
    print(f"precision@5: {result['precision_at_k']:.3f}")

    old_width = pd.get_option("display.max_colwidth")
    pd.set_option("display.max_colwidth", None)
    display(result["recs"])
    pd.set_option("display.max_colwidth", old_width)
# Out:
# Relevant module IDs (ground truth): [191, 233, 375, 377, 379, 385, 387, 388, 389, 391]
# Top-5 recommended IDs: [387, 375, 391, 304, 389]
# Hits in top-5: 4
# precision@5: 0.800
# --------------------------------------------------
# Relevant module IDs (ground truth): [304, 305, 312, 317, 318, 321, 322, 333, 334, 336, 340]
# Top-5 recommended IDs: [304, 305, 337, 334, 310]
# Hits in top-5: 3
# precision@5: 0.600
# --------------------------------------------------
# Relevant module IDs (ground truth): [159, 173, 177, 180, 193, 208, 290, 357, 397]
# Top-5 recommended IDs: [159, 201, 180, 283, 290]
# Hits in top-5: 3
# precision@5: 0.600
# --------------------------------------------------
# Relevant module IDs (ground truth): [229, 235, 237, 279, 280, 380, 381]
# Top-5 recommended IDs: [235, 372, 237, 381, 224]
# Hits in top-5: 3
# precision@5: 0.600
# --------------------------------------------------
# Relevant module IDs (ground truth): [160, 161, 162, 163, 179]
# Top-5 recommended IDs: [179, 189, 178, 365, 190]
# Hits in top-5: 1
# precision@5: 0.200
# --------------------------------------------------
# Average precision@5 over all students: 0.56
# ============================================================
# Results for Student 1 (index 1):
# precision@5: 0.800
#    rank  module_id                               module_name     score  \
# 0     1        387                               Write Loud   0.355001
# 1     2        375                   Animatie / Storytelling  0.271702
# 2     3        391  Art & Humanity (nieuwe naam formuleren)   0.236553
# 3     4        304          Robotic AI Interfaces - optie 1*  0.225898
# 4     5        389                       Performance in Art   0.225731
#
#                                                                                                                                                                                                            motivation_full
# 0  Op basis van jouw antwoorden kan alsnog relevant zijn op basis van delen van jouw profiel. Je profiel benadrukt vooral "leren hoe ik betere illustraties kan maken zowel analoog als digitaal", wat hier goed bij past.
# 1                                                 Op basis van jouw antwoorden kan een interessante extra optie zijn. Dit sluit aan bij wat je vertelt: "Tekenen Animatie Kunst Drama Ik hou ervan om mensen te vermaken".
# 2                    Op basis van jouw antwoorden kan alsnog relevant zijn op basis van delen van jouw profiel. Dit sluit aan bij wat je vertelt: "leren hoe ik betere illustraties kan maken zowel analoog als digitaal".
# 3                         Op basis van jouw antwoorden kan een interessante extra optie zijn. Je profiel benadrukt vooral "leren hoe ik betere illustraties kan maken zowel analoog als digitaal", wat hier goed bij past.
# 4                 Performance in Art  kan alsnog relevant zijn op basis van delen van jouw profiel. Je profiel benadrukt vooral "Tekenen Animatie Kunst Drama Ik hou ervan om mensen te vermaken", wat hier goed bij past.
# ============================================================
# Results for Student 2 (index 2):
# precision@5: 0.600
#    rank  module_id                       module_name     score  \
# 0     1        304  Robotic AI Interfaces - optie 1*  0.289378
# 1     2        305  Robotic AI Interfaces - optie 2*  0.267246
# 2     3        337              Industriële robotcel  0.264193
# 3     4        334            Artifical Intelligence  0.258030
# 4     5        310                Machines in Motion  0.245444
#
#                                                                                                                                                                                                                                           motivation_full
# 0  Robotic AI Interfaces - optie 1* kan alsnog relevant zijn op basis van delen van jouw profiel. Vooral omdat je aangeeft: "Programmeren AI Coderen Techniek Software Ik heb werken met computers en techniek van jongs af aan al interessant gevonden".
# 1                                                         Deze module kan een interessante extra optie zijn. Dit sluit aan bij wat je vertelt: "Kunstmatige intelligentie is nu ook zeker iets dat me interesseert, zeker met de sterke opkomst hiervan".
# 2          Deze module heeft een gematigde overlap met jouw interesses. Je profiel benadrukt vooral "Programmeren AI Coderen Techniek Software Ik heb werken met computers en techniek van jongs af aan al interessant gevonden", wat hier goed bij past.
# 3                                                                                          Artifical Intelligence kan een interessante extra optie zijn. We herkennen hierin wat je schreef: "Zo kun je denken aan machine learning, deep learning, etc".
# 4                                                          Op basis van jouw antwoorden heeft een gematigde overlap met jouw interesses. Je profiel benadrukt vooral "Zo kun je denken aan machine learning, deep learning, etc", wat hier goed bij past.
# ============================================================
# Results for Student 3 (index 3):
# precision@5: 0.600
#    rank  module_id                                       module_name  \
# 0     1        159                      Kennismaking met Psychologie
# 1     2        201                             Positieve psychiatrie
# 2     3        180                  Jongeren en actuele problematiek
# 3     4        283                                      Safety First
# 4     5        290  Organizational Behavior (samenwerking HRM - IVK)
#
#       score  \
# 0  0.232931
# 1  0.217830
# 2  0.212416
# 3  0.210566
# 4  0.208965
#
#                                                                                                                                                                                                                                            motivation_full
# 0      Kennismaking met Psychologie heeft een gematigde overlap met jouw interesses. Je profiel benadrukt vooral "Kritisch denken Sociale Vaardigheden Ik wil leren hoe ik mensen en hun gedrag beter kan analyseren Psychologie", wat hier goed bij past.
# 1                                     Positieve psychiatrie kan alsnog relevant zijn op basis van delen van jouw profiel. Dit sluit aan bij wat je vertelt: "Graag wil ik mensen hun welzijn kunnen bevorderen met het gebruik van psychologische kennis".
# 2                  Jongeren en actuele problematiek heeft een gematigde overlap met jouw interesses. We herkennen hierin wat je schreef: "Kritisch denken Sociale Vaardigheden Ik wil leren hoe ik mensen en hun gedrag beter kan analyseren Psychologie".
# 3                                    Deze module kan alsnog relevant zijn op basis van delen van jouw profiel. Vooral omdat je aangeeft: "Kritisch denken Sociale Vaardigheden Ik wil leren hoe ik mensen en hun gedrag beter kan analyseren Psychologie".
# 4  Organizational Behavior (samenwerking HRM - IVK) heeft een gematigde overlap met jouw interesses. We herkennen hierin wat je schreef: "Kritisch denken Sociale Vaardigheden Ik wil leren hoe ik mensen en hun gedrag beter kan analyseren Psychologie".
# ============================================================
# Results for Student 4 (index 4):
# precision@5: 0.600
#    rank  module_id                                             module_name  \
# 0     1        235                                            BI Innovatie
# 1     2        372       Innovation for sustainability \r\n(SDG in motion)
# 2     3        237                             BI Onderzoek voor innovatie
# 3     4        381             Innovation management & creative leadership
# 4     5        224  Biobased Technology and Business Development. Zie ALST
#
#       score  \
# 0  0.317182
# 1  0.298247
# 2  0.294224
# 3  0.278411
# 4  0.275712
#
#                                                                                                                                                                                                                                                                                          motivation_full
# 0                                                                                                                                        Deze module kan een interessante extra optie zijn. Je profiel benadrukt vooral "I am especially interested in innovation and strategy", wat hier goed bij past.
# 1                                                                   Deze module kan een interessante extra optie zijn. Vooral omdat je aangeeft: "Also, how future developments influence economic growth and organizational success Forward thinking Social skill I want to better understand the ...".
# 2  BI Onderzoek voor innovatie kan alsnog relevant zijn op basis van delen van jouw profiel. Je profiel benadrukt vooral "Also, how future developments influence economic growth and organizational success Forward thinking Social skill I want to better understand the ...", wat hier goed bij past.
# 3                                                                                                                        Innovation management & creative leadership kan een interessante extra optie zijn. We herkennen hierin wat je schreef: "I am especially interested in innovation and strategy".
# 4                                                                                                                             Op basis van jouw antwoorden heeft een gematigde overlap met jouw interesses. We herkennen hierin wat je schreef: "I am especially interested in innovation and strategy".
# ============================================================
# Results for Student 5 (index 5):
# precision@5: 0.200
#    rank  module_id                                  module_name     score  \
# 0     1        179                           Pro-active nursing  0.289104
# 1     2        189                          Kinderfysiotherapie  0.232622
# 2     3        178                                    Oncologie  0.201841
# 3     4        365  Minor Procesautomatisering (Benno de Vries)  0.193510
# 4     5        190                 Healthcare Innovation Design  0.191214
#
#                                                                                                                                                                                                  motivation_full
# 0                  Op basis van jouw antwoorden kan een interessante extra optie zijn. Vooral omdat je aangeeft: "Zorg Ziekenhuis Medisch Verpleegkunde Ik ben geïnteresseerd in verpleegkunde in het algemeen".
# 1  Deze module kan een interessante extra optie zijn. Dit sluit aan bij wat je vertelt: "Sociale vaardigheden Persoonlijke ontwikkeling Ik leren hoe het is om te werken in een ziekenhuisseting Verpleegkunde".
# 2        Op basis van jouw antwoorden kan alsnog relevant zijn op basis van delen van jouw profiel. We herkennen hierin wat je schreef: "Wel lijkt het me leuk als de module mij wat praktische ervaring geeft".
# 3                         Deze module kan alsnog relevant zijn op basis van delen van jouw profiel. We herkennen hierin wat je schreef: "Wel lijkt het me leuk als de module mij wat praktische ervaring geeft".
# 4     Healthcare Innovation Design heeft een gematigde overlap met jouw interesses. Je profiel benadrukt vooral "Wel lijkt het me leuk als de module mij wat praktische ervaring geeft", wat hier goed bij past.
